# %%
cali=[]
def leer (cali):
  for i in range(10):
    cali.append(float(input("Ingrese calificacion: ")))
def promedio (cali):
    prom=[]
    for i in (cali):
      if (i>=8.5):
        prom.append(i)
    return prom
leer (cali)
print("los mayores a 8.5 son: ",promedio(cali))
# Out:
# Ingrese calificacion: 10
# Ingrese calificacion: 9
# Ingrese calificacion: 7
# Ingrese calificacion: 6
# Ingrese calificacion: 10
# Ingrese calificacion: 9.9
# Ingrese calificacion: 8.7
# Ingrese calificacion: 8.6
# Ingrese calificacion: 9
# Ingrese calificacion: 8
# los mayores a 8.5 son:  [10.0, 9.0, 10.0, 9.9, 8.7, 8.6, 9.0]
